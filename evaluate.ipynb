# %%
import pandas as pd
import pypsa
import glob

# %%
runs = []

for run in glob.glob("finished_runs/2025-12-04/*.nc"):
    runs.append(pypsa.Network(run))
# Out:
# INFO:pypsa.network.io:New version 1.0.5 available! (Current: 1.0.3)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/micromamba/envs/open_eraa/lib/python3.12/site-packages/xarray/core/dataarray.py:3887, in DataArray.to_pandas(self)
#    3886 try:
# -> 3887     constructor = constructors[self.ndim]
#    3888 except KeyError as err:
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/micromamba/envs/open_eraa/lib/python3.12/site-packages/pypsa/network/io.py:931, in _ImporterNetCDF.get_series(self, list_name)
#     930 try:
# --> 931     df = self.ds[attr].to_pandas()
#     932     # df.index.name = "name"
#
# File ~/micromamba/envs/open_eraa/lib/python3.12/site-packages/xarray/core/dataarray.py:3889, in DataArray.to_pandas(self)
# ...

# %%
pypsa.Network(run)
# Out:
# INFO:pypsa.network.io:New version 1.0.5 available! (Current: 1.0.3)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/micromamba/envs/open_eraa/lib/python3.12/site-packages/xarray/core/dataarray.py:3887, in DataArray.to_pandas(self)
#    3886 try:
# -> 3887     constructor = constructors[self.ndim]
#    3888 except KeyError as err:
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/micromamba/envs/open_eraa/lib/python3.12/site-packages/pypsa/network/io.py:931, in _ImporterNetCDF.get_series(self, list_name)
#     930 try:
# --> 931     df = self.ds[attr].to_pandas()
#     932     # df.index.name = "name"
#
# File ~/micromamba/envs/open_eraa/lib/python3.12/site-packages/xarray/core/dataarray.py:3889, in DataArray.to_pandas(self)
# ...
