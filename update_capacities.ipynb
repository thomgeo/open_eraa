# %%
import pandas as pd
import pypsa

# %%
import os

# %%
save_path = "resources/networks/1/cy1983_ty2027.nc"

# %%
n = pypsa.Network("resources/networks/0/cy1982_ty2027.nc")
# Out:
# INFO:pypsa.io:Imported network cy1982_ty2027.nc has buses, generators, links, loads, storage_units

# %%
target_year = 2027
climate_year = 1982

# %%
capacity_table = pd.read_csv("resources/capacity_tables/1.csv", index_col=[0,1])

# %%
capacity_table = capacity_table.loc[:, target_year,:]

# %%
update = capacity_table.index.intersection(n.generators.index)

n.generators.loc[update, "p_nom"] = capacity_table.loc[update, "p_nom"]

# %%
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# %%
n.export_to_netcdf("resources/networks/1/cy1982_ty2025.nc")
# Out:
# INFO:pypsa.io:Exported network cy1982_ty2025.nc has generators, buses, storage_units, links, loads
# <xarray.Dataset>
# Dimensions:                       (snapshots: 8760, investment_periods: 0,
#                                    generators_i: 554,
#                                    generators_t_p_max_pu_i: 158, buses_i: 53,
#                                    storage_units_i: 80,
#                                    storage_units_t_inflow_i: 33, links_i: 200,
#                                    links_t_p_max_pu_i: 200, loads_i: 49,
#                                    loads_t_p_set_i: 49)
# Coordinates:
#   * snapshots                     (snapshots) int64 0 1 2 3 ... 8757 8758 8759
#   * investment_periods            (investment_periods) int64
#   * generators_i                  (generators_i) object 'AL00 CCGT' ... 'UKNI...
#   * generators_t_p_max_pu_i       (generators_t_p_max_pu_i) object 'AL00 onwi...
# ...
