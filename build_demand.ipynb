# %%
import pandas as pd
import numpy as np
import glob
import zipfile
import os

# %%
save_hdf="resources/demand.h5"

# %%
with zipfile.ZipFile("data/demand.zip") as zip_f:
    zip_f.extractall("data/demand/")

# %%
files = glob.glob("data/demand/Demand data/Demand timeseries/*")

# %%
file = files[0]

# %%
    
    print("\n" + file + "\n")

    #demand_excel = pd.ExcelFile(file)

    demand_target_year = pd.DataFrame()

    zone = os.path.splitext(os.path.basename(file))[0].split("_")[0]
# Out:
# data/demand/Demand data/Demand timeseries/GR03_Demand_total_2028_National Trends.csv

# %%
        
#    demand_target_year[zone] = 
pd.read_csv(file, index_col=[0,3], header=0).iloc[:,2:].reset_index(drop=True).stack()
# Out:
# 0     WS01    225.013
#       WS02    213.470
#       WS03    240.929
#       WS04    238.743
#       WS05    211.469
#                ...
# 8759  WS32    302.194
#       WS33    255.826
#       WS34    287.470
#       WS35    251.456
#       WS36    266.578
# Length: 315360, dtype: float64

# %%
demand_target_year
# Out:
#                GR03
# 0    Month    1.000
#      Day      1.000
#      WS01   225.013
#      WS02   213.470
#      WS03   240.929
# ...             ...
# 8759 WS32   302.194
#      WS33   255.826
#      WS34   287.470
#      WS35   251.456
#      WS36   266.578
#
# [332880 rows x 1 columns]

# %%
    demand_target_year = demand_target_year.stack()

    target_year = os.path.splitext(os.path.basename(file))[0].split("_")[3]

    demand_target_year.name=target_year
    
    demand = pd.concat([demand, demand_target_year], axis=1)

# %%
demand_excel = pd.ExcelFile(file)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-6-9b2a7c32e828> in <module>
# ----> 1 demand_excel = pd.ExcelFile(file)
#
# /trinity/shared/apps/anaconda3/2020.11/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# /trinity/shared/apps/anaconda3/2020.11/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# ...

# %%
demand = pd.DataFrame()

for file in files:
    
    print("\n" + file + "\n")

    demand_excel = pd.ExcelFile(file)

    demand_target_year = pd.DataFrame()
    for zone in demand_excel.sheet_names:
        
        print(zone)
        
        demand_target_year[zone] = pd.read_excel(demand_excel, zone, index_col=[0,1], header=1).reset_index(drop=True).stack()

    demand_target_year = demand_target_year.stack()

    target_year = os.path.splitext(os.path.basename(file))[0].split("TY")[1]

    demand_target_year.name=target_year
    
    demand = pd.concat([demand, demand_target_year], axis=1)
# Out:
# data/demand/Demand_Timeseries_TY2030.xlsx
#
# AL00
# AT00
# BA00
# BE00
# BG00
# CH00
# CY00
# CZ00
# DE00
# DKE1
# DKW1
# EE00
# ES00
# FI00
# FR00
# GR00
# GR03
# HR00
# HU00
# IE00
# ITCA
# ITCN
# ITCS
# ITN1
# ITS1
# ITSA
# ITSI
# LT00
# LUB1
# LUF1
# LUG1
# LV00
# ME00
# MK00
# MT00
# NL00
# NOM1
# NON1
# NOS0
# PL00
# PT00
# RO00
# RS00
# SE01
# SE02
# SE03
# SE04
# SI00
# SK00
# TR00
# UK00
# UKNI
#
# data/demand/Demand_Timeseries_TY2028.xlsx
#
# AL00
# AT00
# BA00
# BE00
# BG00
# CH00
# CY00
# CZ00
# DE00
# DKE1
# DKW1
# EE00
# ES00
# FI00
# FR00
# GR00
# GR03
# HR00
# HU00
# IE00
# ITCA
# ITCN
# ITCS
# ITN1
# ITS1
# ITSA
# ITSI
# LT00
# LUB1
# LUF1
# LUG1
# LV00
# ME00
# MK00
# MT00
# NL00
# NOM1
# NON1
# NOS0
# PL00
# PT00
# RO00
# RS00
# SE01
# SE02
# SE03
# SE04
# SI00
# SK00
# TR00
# UK00
# UKNI
#
# data/demand/Demand_Timeseries_TY2025.xlsx
#
# AL00
# AT00
# BA00
# BE00
# BG00
# CH00
# CY00
# CZ00
# DE00
# DKE1
# DKW1
# EE00
# ES00
# FI00
# FR00
# GR00
# GR03
# HR00
# ...

# %%
demand = demand.stack()

# %%
demand.index.names = ["hour", "climate year", "zone", "target year"]

# %%
dirname = os.path.dirname(save_hdf)

if not os.path.exists(dirname):
    os.mkdir(dirname)

# %%
demand.to_hdf(save_hdf, "demand")
